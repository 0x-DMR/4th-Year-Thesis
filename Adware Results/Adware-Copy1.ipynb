# %%
# The following section is used to generate information about the datasets so these 
# variables can be initialised in the CNN Model. The information gathered here will
# also be used to determine an appropiate size of the training and testing datasets.
import os                                                   # Import os to change the information surrounding the enviroment 
from keras.preprocessing.image import ImageDataGenerator    # Create tensorflow image batches using data augmentation.
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
locationOfDataset = '/home/dmr/DatasetForExperiments/adware/'
batches = ImageDataGenerator().flow_from_directory(directory=locationOfDataset, target_size=(64,64), batch_size=10000)

# Print information about Images 
imgs, labels = next(batches)
print("Number of Images and Size of Images: ",imgs.shape) # Images with width x length x depth
print("Number of Images and Families: ",labels.shape) # Lablels with batch_size, number of classes
# Out:
# 2023-05-05 12:58:23.539006: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Found 107 images belonging to 10 classes.
# Number of Images and Size of Images:  (107, 64, 64, 3)
# Number of Images and Families:  (107, 10)

# %%
# This section will cover the necessary steps used to split the scareware dataset
# into training and testing to evaluate the effectiveness of this convolutional neural 
# network model based on the scareware samples.
import numpy as np                                   # Provides the ability to use numerical data to convert the .dex files to greyscale images
import scipy as sp                                   # Provides the use of algorithms to be used 
from PIL import Image                                # Allow for processing of images

# Splitting the Dataset into Training and testing with a test size of 30% of overall 
# samples in the dataset. 
from sklearn.model_selection import train_test_split    # Used to split the dataset

# Split up the data set, 30% testing 70% training
trainX, testX, trainY, testY = train_test_split(imgs/255.,labels, test_size=0.3)

# Print the information regarding the training and testing sample sizes
#print("Size of Training Set: ", trainX.shape)                   # Print training set information
#print("Size of Testing Set: ",testX.shape)                      # Print testing set information
print("Number of Samples in Training Set: ",trainY.shape)   # Print training set information
print("Number of Samples in Testing Set: ",testY.shape)     # Print testing set information
# Out:
# Number of Samples in Training Set:  (74, 10)
# Number of Samples in Testing Set:  (33, 10)

# %%
# The Convolutional Neural Network Model
# This section will encompass the aspects surrounding the convultional neural network
# which was used for the experimentation of this research. 
import keras                                            # Import keras
import tensorflow                                       # Import tensorflow
from keras.models import Sequential, Input, Model       # Used for CNN model regarding Models
from keras.layers import Dense, Dropout, Flatten        # Used for CNN model regarding Layers
from keras.layers import Conv2D, MaxPooling2D           # Used for CNN model regarding Layers
from tensorflow.keras.layers import BatchNormalization  # Layer used to normalise inputs
from tensorflow.keras.metrics import AUC                # Used estimate to Area Under Curve

noOfFamilies = 10 # Number of Families in the Sample

# Function used to create the layers of the convolutional neural network model. These parameters were
# constantly changed throughout testing in order to obtain the best possible results. Within this model 
# there are 10 main layers and each layers parameters are explained in detail. 
def CNNModel():
    CNNModel = Sequential()        # Sequential Model is used the experiments

    # Convolutional Layer: With relu Activation, 30 filters, and a kernel size of 3 x 3
    CNNModel.add(Conv2D(30, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(64,64,3)))                # Layer 1 

    # Max Pooling Layer: With a pool size of 2 x 2
    CNNModel.add(MaxPooling2D(pool_size=(2, 2)))            # Layer 2
    
    # Convolutional Layer: 15 filters and kernel size of 3 x 3 
    CNNModel.add(Conv2D(15, (3, 3), activation='relu'))     # Layer 3
    
    # Max Pooling Layer: Pool size of 2 x 2 
    CNNModel.add(MaxPooling2D(pool_size=(2, 2)))            # Layer 4
    
    # Drop Out Layer: This layer used to drop 25% of neurons in the model .
    CNNModel.add(Dropout(0.25))                             # Layer 5
    
    # Flatten Layer
    CNNModel.add(Flatten())                                 # Layer 6
    
    # Dense/Fully Connected Layer : 128 Neurons using the relu activation function
    CNNModel.add(Dense(128, activation='relu'))             # Layer 7
    
    # Drop Out Layer: This layer used to drop 50% of neurons in the model.
    CNNModel.add(Dropout(0.5))                              # Layer 8
    
    # Dense/Fully Connected Layer : 50 Neurons using the relu activation function
    CNNModel.add(Dense(50, activation='relu'))              # Layer 9
    
    # Dense/Fully Connected Layer : number of families neurons, using the softmax activation function
    CNNModel.add(Dense(noOfFamilies, activation='softmax')) # Layer 10
    
    CNNModel.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return CNNModel     # Return the Convolutional Neural Network Model

# %%
# Measure the effectiveness of the model. This section is used to generate the results of the 
# corresponding convolutional neural network. For the purpose of this mode, there are three main 
# measurements which have to be declared. These are recall, preicision and f1. Listed below
# are the neccessary formulas which are required to obtain these results.
from keras import backend as K

# Recall Measurement
def recallMeasurement(testY, yPrediction):
    true_positives = K.sum(K.round(K.clip(testY * yPrediction, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(testY, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# Precision Measurement
def precisionMeasurement(testY, yPrediction):
    true_positives = K.sum(K.round(K.clip(testY * yPrediction, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(yPrediction, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# F1 Measurement
def f1Measurement(testY, yPrediction):
    precision = precisionMeasurement(testY, yPrediction)
    recall = recallMeasurement(testY, yPrediction)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Initialise the Model
CNNModel = CNNModel()
# Out:
# 2023-05-05 12:58:26.603496: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-05-05 12:58:26.914733: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-05-05 12:58:26.914813: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pop-os): /proc/driver/nvidia/version does not exist
# 2023-05-05 12:58:26.916583: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 12:58:26.932454: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1999965000 Hz
# 2023-05-05 12:58:26.934615: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e14620 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-05-05 12:58:26.934687: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
# Print the Information of the Model. This includes the information surrounding 
# the layers of the models as well as the number of total parameters
CNNModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 30)        840
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 30)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 15)        4065
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 15)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 15)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 2940)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               376448
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# =================================================================
# Total params: 388,313
# Trainable params: 388,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
trainY.shape                            # Returns the shape of the trainY array 
trainY_new = np.argmax(trainY, axis=1)  # Converts the trainY array to an array of integers 
trainY_new                              # Returns the array of integer labels
# Out:
# array([9, 8, 7, 0, 1, 0, 3, 2, 5, 7, 0, 2, 3, 9, 0, 3, 3, 2, 6, 4, 7, 3,
#        4, 6, 9, 1, 6, 5, 3, 0, 1, 1, 3, 8, 6, 6, 7, 2, 2, 0, 8, 0, 4, 4,
#        3, 4, 3, 5, 7, 9, 5, 5, 3, 6, 9, 1, 7, 0, 6, 5, 2, 6, 6, 4, 2, 3,
#        1, 7, 4, 3, 4, 1, 2, 2])

# %%
# This section of the model imports the class_weight function from the sklearn.utils 
# library. This is used to compute the class weights for a multi-class classification problem.
# The weightOfModel computes the class weights based on the class distribution found in the 
# training set. The class_weight parameter is set to balanced which means that the class 
# weights are automatically adjusted in acorrdance with the information obtained from the 
# input data.

from sklearn.utils import class_weight # Used to compute the class weights for a multi-class classification system
weightOfModel = class_weight.compute_class_weight(class_weight = 'balanced',
                                                 classes = np.unique(trainY_new),
                                                 y = trainY_new)

# This code is used to map each unique class label in the training set trainY_new variable. 
# This is then uses the class_weight variable initialised above. 
weightOfModel = {l:c for l,c in zip(np.unique(trainY_new), weightOfModel)}

# %%
# This is used to compile the Convolutional Neural network Model. It uses the adam optimiser, 
# computes loss using binary_crossentropy and then calculates the measurements listed before.
CNNModel.compile(optimizer='adam', 
                    loss='binary_crossentropy', 
                    metrics=[f1Measurement,precisionMeasurement, 
                    recallMeasurement,
                    AUC()])

# %%
# This section of the model is used to trained the convolutional neural network model. 
# This is achieved by using the fit() method from the Keras API of the TensorFlow library which 
# was imported previously. Here is where the number of epochs are declared for the model also
CNNModel.fit(trainX, trainY, validation_data=(testX, testY), 
                epochs=150,  
                class_weight=weightOfModel)
# Out:
# 2023-05-05 12:58:27.086815: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Epoch 1/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.6645 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.4436 - val_loss: 0.4464 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4412
# Epoch 2/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4655 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.4242 - val_loss: 0.3679 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4625
# Epoch 3/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3984 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.4502 - val_loss: 0.3456 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5230
# Epoch 4/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3575 - f1Measurement: 0.0570 - precisionMeasurement: 0.1806 - recallMeasurement: 0.0339 - auc: 0.5337 - val_loss: 0.3346 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5062
# Epoch 5/150
# 3/3 [==============================] - 0s 41ms/step - loss: 0.3394 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5727 - val_loss: 0.3417 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4840
# Epoch 6/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3630 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5404 - val_loss: 0.3432 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4685
# Epoch 7/150
# 3/3 [==============================] - 0s 51ms/step - loss: 0.3539 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5313 - val_loss: 0.3460 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4854
# Epoch 8/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.3438 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5182 - val_loss: 0.3322 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5193
# Epoch 9/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3533 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5936 - val_loss: 0.3275 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5870
# Epoch 10/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3222 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.6845 - val_loss: 0.3217 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6282
# Epoch 11/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3424 - f1Measurement: 0.0177 - precisionMeasurement: 0.2917 - recallMeasurement: 0.0091 - auc: 0.6549 - val_loss: 0.3222 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6450
# Epoch 12/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3139 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.6697 - val_loss: 0.3143 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6546
# Epoch 13/150
# 3/3 [==============================] - 0s 52ms/step - loss: 0.3140 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.7014 - val_loss: 0.3147 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6570
# Epoch 14/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2960 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.7946 - val_loss: 0.3137 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6536
# Epoch 15/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2965 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.7347 - val_loss: 0.3171 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6153
# Epoch 16/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2990 - f1Measurement: 0.0505 - precisionMeasurement: 0.8333 - recallMeasurement: 0.0260 - auc: 0.7517 - val_loss: 0.3149 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6126
# Epoch 17/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2903 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.7911 - val_loss: 0.3094 - val_f1Measurement: 0.0303 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0156 - val_auc: 0.6651
# Epoch 18/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2769 - f1Measurement: 0.0962 - precisionMeasurement: 0.6528 - recallMeasurement: 0.0521 - auc: 0.8195 - val_loss: 0.3034 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7170
# Epoch 19/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2718 - f1Measurement: 0.1092 - precisionMeasurement: 0.9167 - recallMeasurement: 0.0596 - auc: 0.8580 - val_loss: 0.2997 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7467
# Epoch 20/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.2571 - f1Measurement: 0.0929 - precisionMeasurement: 0.5417 - recallMeasurement: 0.0508 - auc: 0.8906 - val_loss: 0.2949 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7486
# Epoch 21/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2344 - f1Measurement: 0.2107 - precisionMeasurement: 1.0000 - recallMeasurement: 0.1234 - auc: 0.8878 - val_loss: 0.2904 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7438
# Epoch 22/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.2564 - f1Measurement: 0.2048 - precisionMeasurement: 0.6861 - recallMeasurement: 0.1206 - auc: 0.8663 - val_loss: 0.2889 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7484
# Epoch 23/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.2402 - f1Measurement: 0.2911 - precisionMeasurement: 0.9583 - recallMeasurement: 0.1729 - auc: 0.8791 - val_loss: 0.2918 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7515
# Epoch 24/150
# 3/3 [==============================] - 0s 53ms/step - loss: 0.2313 - f1Measurement: 0.2847 - precisionMeasurement: 0.9323 - recallMeasurement: 0.1716 - auc: 0.8832 - val_loss: 0.2941 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7420
# Epoch 25/150
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2187 - f1Measurement: 0.3680 - precisionMeasurement: 0.7944 - recallMeasurement: 0.2417 - auc: 0.8986 - val_loss: 0.2905 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7589
# Epoch 26/150
# 3/3 [==============================] - 0s 51ms/step - loss: 0.2119 - f1Measurement: 0.3951 - precisionMeasurement: 0.8990 - recallMeasurement: 0.2581 - auc: 0.9267 - val_loss: 0.2830 - val_f1Measurement: 0.0857 - val_precisionMeasurement: 0.5000 - val_recallMeasurement: 0.0469 - val_auc: 0.7805
# Epoch 27/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2093 - f1Measurement: 0.3824 - precisionMeasurement: 0.7399 - recallMeasurement: 0.2583 - auc: 0.9210 - val_loss: 0.2788 - val_f1Measurement: 0.1190 - val_precisionMeasurement: 0.2500 - val_recallMeasurement: 0.0781 - val_auc: 0.7957
# Epoch 28/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1843 - f1Measurement: 0.5310 - precisionMeasurement: 0.7647 - recallMeasurement: 0.4115 - auc: 0.9480 - val_loss: 0.2865 - val_f1Measurement: 0.1163 - val_precisionMeasurement: 0.2273 - val_recallMeasurement: 0.0781 - val_auc: 0.7899
# Epoch 29/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1873 - f1Measurement: 0.5249 - precisionMeasurement: 0.8109 - recallMeasurement: 0.3885 - auc: 0.9412 - val_loss: 0.2901 - val_f1Measurement: 0.1026 - val_precisionMeasurement: 0.2857 - val_recallMeasurement: 0.0625 - val_auc: 0.7636
# Epoch 30/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1847 - f1Measurement: 0.5419 - precisionMeasurement: 0.8319 - recallMeasurement: 0.4039 - auc: 0.9457 - val_loss: 0.2846 - val_f1Measurement: 0.1026 - val_precisionMeasurement: 0.2857 - val_recallMeasurement: 0.0625 - val_auc: 0.7691
# Epoch 31/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1766 - f1Measurement: 0.5645 - precisionMeasurement: 0.8244 - recallMeasurement: 0.4312 - auc: 0.9454 - val_loss: 0.2820 - val_f1Measurement: 0.1250 - val_precisionMeasurement: 0.3125 - val_recallMeasurement: 0.0781 - val_auc: 0.7779
# Epoch 32/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1573 - f1Measurement: 0.6955 - precisionMeasurement: 0.8705 - recallMeasurement: 0.5844 - auc: 0.9656 - val_loss: 0.2899 - val_f1Measurement: 0.1364 - val_precisionMeasurement: 0.2500 - val_recallMeasurement: 0.0938 - val_auc: 0.7846
# Epoch 33/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1636 - f1Measurement: 0.6912 - precisionMeasurement: 0.8811 - recallMeasurement: 0.5758 - auc: 0.9671 - val_loss: 0.2749 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.2308 - val_recallMeasurement: 0.0938 - val_auc: 0.7982
# Epoch 34/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1478 - f1Measurement: 0.6564 - precisionMeasurement: 0.8493 - recallMeasurement: 0.5352 - auc: 0.9727 - val_loss: 0.2762 - val_f1Measurement: 0.1522 - val_precisionMeasurement: 0.2500 - val_recallMeasurement: 0.1094 - val_auc: 0.7901
# Epoch 35/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1492 - f1Measurement: 0.7028 - precisionMeasurement: 0.8595 - recallMeasurement: 0.6021 - auc: 0.9673 - val_loss: 0.3040 - val_f1Measurement: 0.1064 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.0781 - val_auc: 0.7749
# Epoch 36/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1394 - f1Measurement: 0.7238 - precisionMeasurement: 0.8576 - recallMeasurement: 0.6273 - auc: 0.9715 - val_loss: 0.3115 - val_f1Measurement: 0.1224 - val_precisionMeasurement: 0.1765 - val_recallMeasurement: 0.0938 - val_auc: 0.7692
# Epoch 37/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1400 - f1Measurement: 0.7512 - precisionMeasurement: 0.8507 - recallMeasurement: 0.6729 - auc: 0.9753 - val_loss: 0.2765 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.2059 - val_recallMeasurement: 0.1094 - val_auc: 0.7979
# Epoch 38/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1313 - f1Measurement: 0.7071 - precisionMeasurement: 0.8274 - recallMeasurement: 0.6198 - auc: 0.9828 - val_loss: 0.2686 - val_f1Measurement: 0.1400 - val_precisionMeasurement: 0.1944 - val_recallMeasurement: 0.1094 - val_auc: 0.8061
# Epoch 39/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1230 - f1Measurement: 0.7670 - precisionMeasurement: 0.9131 - recallMeasurement: 0.6620 - auc: 0.9850 - val_loss: 0.2935 - val_f1Measurement: 0.1346 - val_precisionMeasurement: 0.1750 - val_recallMeasurement: 0.1094 - val_auc: 0.7940
# Epoch 40/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1138 - f1Measurement: 0.7891 - precisionMeasurement: 0.9206 - recallMeasurement: 0.6909 - auc: 0.9773 - val_loss: 0.3120 - val_f1Measurement: 0.1373 - val_precisionMeasurement: 0.1842 - val_recallMeasurement: 0.1094 - val_auc: 0.7918
# Epoch 41/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.1073 - f1Measurement: 0.7493 - precisionMeasurement: 0.8101 - recallMeasurement: 0.6974 - auc: 0.9863 - val_loss: 0.3013 - val_f1Measurement: 0.1481 - val_precisionMeasurement: 0.1818 - val_recallMeasurement: 0.1250 - val_auc: 0.7878
# Epoch 42/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1033 - f1Measurement: 0.7874 - precisionMeasurement: 0.8634 - recallMeasurement: 0.7242 - auc: 0.9837 - val_loss: 0.2949 - val_f1Measurement: 0.0962 - val_precisionMeasurement: 0.1250 - val_recallMeasurement: 0.0781 - val_auc: 0.7906
# Epoch 43/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0925 - f1Measurement: 0.8463 - precisionMeasurement: 0.8951 - recallMeasurement: 0.8029 - auc: 0.9943 - val_loss: 0.3056 - val_f1Measurement: 0.0980 - val_precisionMeasurement: 0.1316 - val_recallMeasurement: 0.0781 - val_auc: 0.7830
# Epoch 44/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0996 - f1Measurement: 0.7767 - precisionMeasurement: 0.8588 - recallMeasurement: 0.7091 - auc: 0.9859 - val_loss: 0.3277 - val_f1Measurement: 0.1481 - val_precisionMeasurement: 0.1818 - val_recallMeasurement: 0.1250 - val_auc: 0.7773
# Epoch 45/150
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0912 - f1Measurement: 0.8414 - precisionMeasurement: 0.9190 - recallMeasurement: 0.7766 - auc: 0.9919 - val_loss: 0.3346 - val_f1Measurement: 0.1481 - val_precisionMeasurement: 0.1818 - val_recallMeasurement: 0.1250 - val_auc: 0.7802
# Epoch 46/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0896 - f1Measurement: 0.8520 - precisionMeasurement: 0.8919 - recallMeasurement: 0.8164 - auc: 0.9932 - val_loss: 0.3052 - val_f1Measurement: 0.1346 - val_precisionMeasurement: 0.1750 - val_recallMeasurement: 0.1094 - val_auc: 0.7944
# Epoch 47/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0858 - f1Measurement: 0.8761 - precisionMeasurement: 0.8920 - recallMeasurement: 0.8609 - auc: 0.9931 - val_loss: 0.3157 - val_f1Measurement: 0.1538 - val_precisionMeasurement: 0.2000 - val_recallMeasurement: 0.1250 - val_auc: 0.7888
# Epoch 48/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0855 - f1Measurement: 0.8594 - precisionMeasurement: 0.8833 - recallMeasurement: 0.8378 - auc: 0.9910 - val_loss: 0.3303 - val_f1Measurement: 0.1509 - val_precisionMeasurement: 0.1905 - val_recallMeasurement: 0.1250 - val_auc: 0.7832
# Epoch 49/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0765 - f1Measurement: 0.8167 - precisionMeasurement: 0.8529 - recallMeasurement: 0.7849 - auc: 0.9906 - val_loss: 0.3195 - val_f1Measurement: 0.1296 - val_precisionMeasurement: 0.1591 - val_recallMeasurement: 0.1094 - val_auc: 0.7833
# Epoch 50/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0843 - f1Measurement: 0.8702 - precisionMeasurement: 0.9410 - recallMeasurement: 0.8104 - auc: 0.9919 - val_loss: 0.3076 - val_f1Measurement: 0.1273 - val_precisionMeasurement: 0.1522 - val_recallMeasurement: 0.1094 - val_auc: 0.7889
# Epoch 51/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0714 - f1Measurement: 0.8862 - precisionMeasurement: 0.9237 - recallMeasurement: 0.8518 - auc: 0.9931 - val_loss: 0.3133 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1250 - val_auc: 0.7973
# Epoch 52/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0660 - f1Measurement: 0.8514 - precisionMeasurement: 0.9003 - recallMeasurement: 0.8086 - auc: 0.9937 - val_loss: 0.3427 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1250 - val_auc: 0.8039
# Epoch 53/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0697 - f1Measurement: 0.8492 - precisionMeasurement: 0.8730 - recallMeasurement: 0.8281 - auc: 0.9941 - val_loss: 0.3504 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.8058
# Epoch 54/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0750 - f1Measurement: 0.8620 - precisionMeasurement: 0.9204 - recallMeasurement: 0.8115 - auc: 0.9949 - val_loss: 0.3252 - val_f1Measurement: 0.1273 - val_precisionMeasurement: 0.1522 - val_recallMeasurement: 0.1094 - val_auc: 0.7881
# Epoch 55/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0818 - f1Measurement: 0.7902 - precisionMeasurement: 0.8360 - recallMeasurement: 0.7492 - auc: 0.9890 - val_loss: 0.3149 - val_f1Measurement: 0.1296 - val_precisionMeasurement: 0.1591 - val_recallMeasurement: 0.1094 - val_auc: 0.7994
# Epoch 56/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0617 - f1Measurement: 0.8689 - precisionMeasurement: 0.9034 - recallMeasurement: 0.8383 - auc: 0.9933 - val_loss: 0.3265 - val_f1Measurement: 0.1296 - val_precisionMeasurement: 0.1591 - val_recallMeasurement: 0.1094 - val_auc: 0.8053
# Epoch 57/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0745 - f1Measurement: 0.8511 - precisionMeasurement: 0.8750 - recallMeasurement: 0.8286 - auc: 0.9919 - val_loss: 0.3776 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1250 - val_auc: 0.7891
# Epoch 58/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0716 - f1Measurement: 0.8398 - precisionMeasurement: 0.8439 - recallMeasurement: 0.8359 - auc: 0.9890 - val_loss: 0.3881 - val_f1Measurement: 0.1455 - val_precisionMeasurement: 0.1739 - val_recallMeasurement: 0.1250 - val_auc: 0.7724
# Epoch 59/150
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0598 - f1Measurement: 0.8566 - precisionMeasurement: 0.8686 - recallMeasurement: 0.8456 - auc: 0.9967 - val_loss: 0.3501 - val_f1Measurement: 0.1607 - val_precisionMeasurement: 0.1875 - val_recallMeasurement: 0.1406 - val_auc: 0.7851
# Epoch 60/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0626 - f1Measurement: 0.8931 - precisionMeasurement: 0.9174 - recallMeasurement: 0.8703 - auc: 0.9964 - val_loss: 0.3204 - val_f1Measurement: 0.1273 - val_precisionMeasurement: 0.1522 - val_recallMeasurement: 0.1094 - val_auc: 0.8080
# Epoch 61/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0543 - f1Measurement: 0.9148 - precisionMeasurement: 0.9449 - recallMeasurement: 0.8870 - auc: 0.9959 - val_loss: 0.3362 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.7972
# Epoch 62/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0534 - f1Measurement: 0.9141 - precisionMeasurement: 0.9141 - recallMeasurement: 0.9141 - auc: 0.9952 - val_loss: 0.3715 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7875
# Epoch 63/150
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0499 - f1Measurement: 0.8968 - precisionMeasurement: 0.9043 - recallMeasurement: 0.8896 - auc: 0.9950 - val_loss: 0.4065 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7897
# Epoch 64/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0550 - f1Measurement: 0.8661 - precisionMeasurement: 0.8780 - recallMeasurement: 0.8547 - auc: 0.9956 - val_loss: 0.4067 - val_f1Measurement: 0.1475 - val_precisionMeasurement: 0.1552 - val_recallMeasurement: 0.1406 - val_auc: 0.7632
# Epoch 65/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0644 - f1Measurement: 0.8628 - precisionMeasurement: 0.8915 - recallMeasurement: 0.8365 - auc: 0.9928 - val_loss: 0.3579 - val_f1Measurement: 0.1667 - val_precisionMeasurement: 0.1786 - val_recallMeasurement: 0.1562 - val_auc: 0.7724
# Epoch 66/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0549 - f1Measurement: 0.8528 - precisionMeasurement: 0.8603 - recallMeasurement: 0.8456 - auc: 0.9962 - val_loss: 0.3408 - val_f1Measurement: 0.1579 - val_precisionMeasurement: 0.1800 - val_recallMeasurement: 0.1406 - val_auc: 0.7873
# Epoch 67/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0513 - f1Measurement: 0.8301 - precisionMeasurement: 0.8477 - recallMeasurement: 0.8135 - auc: 0.9958 - val_loss: 0.3551 - val_f1Measurement: 0.1579 - val_precisionMeasurement: 0.1800 - val_recallMeasurement: 0.1406 - val_auc: 0.7837
# Epoch 68/150
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0424 - f1Measurement: 0.8999 - precisionMeasurement: 0.9041 - recallMeasurement: 0.8958 - auc: 0.9984 - val_loss: 0.3907 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7823
# Epoch 69/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0391 - f1Measurement: 0.9054 - precisionMeasurement: 0.9135 - recallMeasurement: 0.8977 - auc: 0.9982 - val_loss: 0.4103 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7890
# Epoch 70/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0495 - f1Measurement: 0.8973 - precisionMeasurement: 0.9270 - recallMeasurement: 0.8701 - auc: 0.9975 - val_loss: 0.3837 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7927
# Epoch 71/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0450 - f1Measurement: 0.8885 - precisionMeasurement: 0.8885 - recallMeasurement: 0.8885 - auc: 0.9968 - val_loss: 0.3699 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7922
# Epoch 72/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0510 - f1Measurement: 0.9044 - precisionMeasurement: 0.9199 - recallMeasurement: 0.8898 - auc: 0.9957 - val_loss: 0.3767 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7942
# Epoch 73/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0404 - f1Measurement: 0.8643 - precisionMeasurement: 0.8643 - recallMeasurement: 0.8643 - auc: 0.9962 - val_loss: 0.3797 - val_f1Measurement: 0.1290 - val_precisionMeasurement: 0.1333 - val_recallMeasurement: 0.1250 - val_auc: 0.7931
# Epoch 74/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0516 - f1Measurement: 0.8820 - precisionMeasurement: 0.8820 - recallMeasurement: 0.8820 - auc: 0.9956 - val_loss: 0.3824 - val_f1Measurement: 0.1311 - val_precisionMeasurement: 0.1379 - val_recallMeasurement: 0.1250 - val_auc: 0.7831
# Epoch 75/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0503 - f1Measurement: 0.9090 - precisionMeasurement: 0.9213 - recallMeasurement: 0.8977 - auc: 0.9960 - val_loss: 0.3746 - val_f1Measurement: 0.1186 - val_precisionMeasurement: 0.1296 - val_recallMeasurement: 0.1094 - val_auc: 0.8030
# Epoch 76/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0522 - f1Measurement: 0.8622 - precisionMeasurement: 0.8622 - recallMeasurement: 0.8622 - auc: 0.9955 - val_loss: 0.3623 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.8117
# Epoch 77/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0429 - f1Measurement: 0.8948 - precisionMeasurement: 0.9028 - recallMeasurement: 0.8870 - auc: 0.9966 - val_loss: 0.3568 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.8074
# Epoch 78/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0377 - f1Measurement: 0.9251 - precisionMeasurement: 0.9376 - recallMeasurement: 0.9130 - auc: 0.9985 - val_loss: 0.3534 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.8122
# Epoch 79/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0487 - f1Measurement: 0.8553 - precisionMeasurement: 0.8742 - recallMeasurement: 0.8375 - auc: 0.9961 - val_loss: 0.3768 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.8056
# Epoch 80/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0447 - f1Measurement: 0.8907 - precisionMeasurement: 0.9027 - recallMeasurement: 0.8792 - auc: 0.9973 - val_loss: 0.4106 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.7963
# Epoch 81/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0456 - f1Measurement: 0.8981 - precisionMeasurement: 0.9099 - recallMeasurement: 0.8867 - auc: 0.9971 - val_loss: 0.4349 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7730
# Epoch 82/150
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0435 - f1Measurement: 0.9221 - precisionMeasurement: 0.9221 - recallMeasurement: 0.9221 - auc: 0.9977 - val_loss: 0.4239 - val_f1Measurement: 0.1250 - val_precisionMeasurement: 0.1458 - val_recallMeasurement: 0.1094 - val_auc: 0.7849
# Epoch 83/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0414 - f1Measurement: 0.8401 - precisionMeasurement: 0.8441 - recallMeasurement: 0.8362 - auc: 0.9958 - val_loss: 0.3940 - val_f1Measurement: 0.1186 - val_precisionMeasurement: 0.1296 - val_recallMeasurement: 0.1094 - val_auc: 0.8001
# Epoch 84/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0375 - f1Measurement: 0.8833 - precisionMeasurement: 0.8954 - recallMeasurement: 0.8716 - auc: 0.9968 - val_loss: 0.3904 - val_f1Measurement: 0.1167 - val_precisionMeasurement: 0.1250 - val_recallMeasurement: 0.1094 - val_auc: 0.7914
# Epoch 85/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0518 - f1Measurement: 0.8805 - precisionMeasurement: 0.9021 - recallMeasurement: 0.8609 - auc: 0.9947 - val_loss: 0.3912 - val_f1Measurement: 0.1311 - val_precisionMeasurement: 0.1379 - val_recallMeasurement: 0.1250 - val_auc: 0.8028
# Epoch 86/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0390 - f1Measurement: 0.8786 - precisionMeasurement: 0.8864 - recallMeasurement: 0.8716 - auc: 0.9964 - val_loss: 0.3945 - val_f1Measurement: 0.1452 - val_precisionMeasurement: 0.1500 - val_recallMeasurement: 0.1406 - val_auc: 0.8006
# Epoch 87/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0402 - f1Measurement: 0.9087 - precisionMeasurement: 0.9207 - recallMeasurement: 0.8971 - auc: 0.9977 - val_loss: 0.4137 - val_f1Measurement: 0.1475 - val_precisionMeasurement: 0.1552 - val_recallMeasurement: 0.1406 - val_auc: 0.7824
# Epoch 88/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0501 - f1Measurement: 0.8467 - precisionMeasurement: 0.8659 - recallMeasurement: 0.8286 - auc: 0.9947 - val_loss: 0.4132 - val_f1Measurement: 0.1452 - val_precisionMeasurement: 0.1500 - val_recallMeasurement: 0.1406 - val_auc: 0.7846
# Epoch 89/150
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0317 - f1Measurement: 0.9173 - precisionMeasurement: 0.9215 - recallMeasurement: 0.9133 - auc: 0.9982 - val_loss: 0.4109 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.1452 - val_recallMeasurement: 0.1406 - val_auc: 0.7897
# Epoch 90/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0479 - f1Measurement: 0.8544 - precisionMeasurement: 0.8544 - recallMeasurement: 0.8544 - auc: 0.9951 - val_loss: 0.4188 - val_f1Measurement: 0.1270 - val_precisionMeasurement: 0.1290 - val_recallMeasurement: 0.1250 - val_auc: 0.8063
# Epoch 91/150
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0316 - f1Measurement: 0.9651 - precisionMeasurement: 0.9651 - recallMeasurement: 0.9651 - auc: 0.9992 - val_loss: 0.4347 - val_f1Measurement: 0.1311 - val_precisionMeasurement: 0.1379 - val_recallMeasurement: 0.1250 - val_auc: 0.7874
# Epoch 92/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0391 - f1Measurement: 0.8666 - precisionMeasurement: 0.8707 - recallMeasurement: 0.8625 - auc: 0.9974 - val_loss: 0.4351 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7800
# Epoch 93/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0385 - f1Measurement: 0.8605 - precisionMeasurement: 0.8663 - recallMeasurement: 0.8552 - auc: 0.9976 - val_loss: 0.4134 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7860
# Epoch 94/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0354 - f1Measurement: 0.8909 - precisionMeasurement: 0.8949 - recallMeasurement: 0.8870 - auc: 0.9975 - val_loss: 0.4073 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7559
# Epoch 95/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0395 - f1Measurement: 0.9121 - precisionMeasurement: 0.9289 - recallMeasurement: 0.8961 - auc: 0.9969 - val_loss: 0.3969 - val_f1Measurement: 0.1296 - val_precisionMeasurement: 0.1591 - val_recallMeasurement: 0.1094 - val_auc: 0.7617
# Epoch 96/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0327 - f1Measurement: 0.9469 - precisionMeasurement: 0.9552 - recallMeasurement: 0.9388 - auc: 0.9983 - val_loss: 0.3982 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.7726
# Epoch 97/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0342 - f1Measurement: 0.9185 - precisionMeasurement: 0.9309 - recallMeasurement: 0.9065 - auc: 0.9984 - val_loss: 0.4171 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7770
# Epoch 98/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0436 - f1Measurement: 0.9114 - precisionMeasurement: 0.9276 - recallMeasurement: 0.8964 - auc: 0.9981 - val_loss: 0.4297 - val_f1Measurement: 0.1311 - val_precisionMeasurement: 0.1379 - val_recallMeasurement: 0.1250 - val_auc: 0.7605
# Epoch 99/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0303 - f1Measurement: 0.9393 - precisionMeasurement: 0.9393 - recallMeasurement: 0.9393 - auc: 0.9986 - val_loss: 0.4462 - val_f1Measurement: 0.1475 - val_precisionMeasurement: 0.1552 - val_recallMeasurement: 0.1406 - val_auc: 0.7515
# Epoch 100/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0338 - f1Measurement: 0.8906 - precisionMeasurement: 0.8947 - recallMeasurement: 0.8867 - auc: 0.9974 - val_loss: 0.4636 - val_f1Measurement: 0.1270 - val_precisionMeasurement: 0.1290 - val_recallMeasurement: 0.1250 - val_auc: 0.7532
# Epoch 101/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0399 - f1Measurement: 0.8593 - precisionMeasurement: 0.8671 - recallMeasurement: 0.8518 - auc: 0.9964 - val_loss: 0.4819 - val_f1Measurement: 0.1270 - val_precisionMeasurement: 0.1290 - val_recallMeasurement: 0.1250 - val_auc: 0.7514
# Epoch 102/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0399 - f1Measurement: 0.9027 - precisionMeasurement: 0.9115 - recallMeasurement: 0.8948 - auc: 0.9964 - val_loss: 0.4516 - val_f1Measurement: 0.1311 - val_precisionMeasurement: 0.1379 - val_recallMeasurement: 0.1250 - val_auc: 0.7383
# Epoch 103/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0401 - f1Measurement: 0.9047 - precisionMeasurement: 0.9125 - recallMeasurement: 0.8977 - auc: 0.9971 - val_loss: 0.4095 - val_f1Measurement: 0.1452 - val_precisionMeasurement: 0.1500 - val_recallMeasurement: 0.1406 - val_auc: 0.7599
# Epoch 104/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0349 - f1Measurement: 0.8885 - precisionMeasurement: 0.8885 - recallMeasurement: 0.8885 - auc: 0.9970 - val_loss: 0.3969 - val_f1Measurement: 0.1695 - val_precisionMeasurement: 0.1852 - val_recallMeasurement: 0.1562 - val_auc: 0.7821
# Epoch 105/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0321 - f1Measurement: 0.8785 - precisionMeasurement: 0.8943 - recallMeasurement: 0.8638 - auc: 0.9973 - val_loss: 0.3959 - val_f1Measurement: 0.1552 - val_precisionMeasurement: 0.1731 - val_recallMeasurement: 0.1406 - val_auc: 0.7796
# Epoch 106/150
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0401 - f1Measurement: 0.8698 - precisionMeasurement: 0.8698 - recallMeasurement: 0.8698 - auc: 0.9957 - val_loss: 0.4137 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7666
# Epoch 107/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0422 - f1Measurement: 0.8292 - precisionMeasurement: 0.8474 - recallMeasurement: 0.8120 - auc: 0.9951 - val_loss: 0.4335 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7568
# Epoch 108/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0349 - f1Measurement: 0.8620 - precisionMeasurement: 0.8620 - recallMeasurement: 0.8620 - auc: 0.9967 - val_loss: 0.4496 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7259
# Epoch 109/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0354 - f1Measurement: 0.9385 - precisionMeasurement: 0.9548 - recallMeasurement: 0.9232 - auc: 0.9969 - val_loss: 0.4607 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7517
# Epoch 110/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0336 - f1Measurement: 0.9044 - precisionMeasurement: 0.9119 - recallMeasurement: 0.8971 - auc: 0.9972 - val_loss: 0.4566 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7574
# Epoch 111/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0343 - f1Measurement: 0.8958 - precisionMeasurement: 0.8958 - recallMeasurement: 0.8958 - auc: 0.9972 - val_loss: 0.4613 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7553
# Epoch 112/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0279 - f1Measurement: 0.9312 - precisionMeasurement: 0.9313 - recallMeasurement: 0.9313 - auc: 0.9988 - val_loss: 0.4745 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7424
# Epoch 113/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0316 - f1Measurement: 0.9326 - precisionMeasurement: 0.9326 - recallMeasurement: 0.9326 - auc: 0.9982 - val_loss: 0.4953 - val_f1Measurement: 0.1250 - val_precisionMeasurement: 0.1458 - val_recallMeasurement: 0.1094 - val_auc: 0.7275
# Epoch 114/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0365 - f1Measurement: 0.8638 - precisionMeasurement: 0.8638 - recallMeasurement: 0.8638 - auc: 0.9970 - val_loss: 0.4955 - val_f1Measurement: 0.1250 - val_precisionMeasurement: 0.1458 - val_recallMeasurement: 0.1094 - val_auc: 0.6893
# Epoch 115/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0361 - f1Measurement: 0.8961 - precisionMeasurement: 0.8961 - recallMeasurement: 0.8961 - auc: 0.9969 - val_loss: 0.4917 - val_f1Measurement: 0.1250 - val_precisionMeasurement: 0.1458 - val_recallMeasurement: 0.1094 - val_auc: 0.6877
# Epoch 116/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0329 - f1Measurement: 0.8872 - precisionMeasurement: 0.8872 - recallMeasurement: 0.8872 - auc: 0.9970 - val_loss: 0.4770 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.7371
# Epoch 117/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0406 - f1Measurement: 0.8859 - precisionMeasurement: 0.8859 - recallMeasurement: 0.8859 - auc: 0.9969 - val_loss: 0.4574 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7191
# Epoch 118/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0318 - f1Measurement: 0.8971 - precisionMeasurement: 0.8971 - recallMeasurement: 0.8971 - auc: 0.9970 - val_loss: 0.4536 - val_f1Measurement: 0.1525 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1406 - val_auc: 0.7077
# Epoch 119/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0450 - f1Measurement: 0.8682 - precisionMeasurement: 0.8915 - recallMeasurement: 0.8466 - auc: 0.9954 - val_loss: 0.4565 - val_f1Measurement: 0.1525 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1406 - val_auc: 0.7044
# Epoch 120/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0332 - f1Measurement: 0.8716 - precisionMeasurement: 0.8716 - recallMeasurement: 0.8716 - auc: 0.9973 - val_loss: 0.4701 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7041
# Epoch 121/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0376 - f1Measurement: 0.8835 - precisionMeasurement: 0.9168 - recallMeasurement: 0.8531 - auc: 0.9968 - val_loss: 0.4737 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7078
# Epoch 122/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0325 - f1Measurement: 0.8781 - precisionMeasurement: 0.8861 - recallMeasurement: 0.8703 - auc: 0.9971 - val_loss: 0.4789 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7109
# Epoch 123/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0294 - f1Measurement: 0.9078 - precisionMeasurement: 0.9284 - recallMeasurement: 0.8883 - auc: 0.9974 - val_loss: 0.4805 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7374
# Epoch 124/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0319 - f1Measurement: 0.8531 - precisionMeasurement: 0.8531 - recallMeasurement: 0.8531 - auc: 0.9970 - val_loss: 0.4864 - val_f1Measurement: 0.1404 - val_precisionMeasurement: 0.1600 - val_recallMeasurement: 0.1250 - val_auc: 0.7287
# Epoch 125/150
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0268 - f1Measurement: 0.9115 - precisionMeasurement: 0.9115 - recallMeasurement: 0.9115 - auc: 0.9980 - val_loss: 0.4920 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7387
# Epoch 126/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0413 - f1Measurement: 0.9219 - precisionMeasurement: 0.9219 - recallMeasurement: 0.9219 - auc: 0.9965 - val_loss: 0.5040 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7401
# Epoch 127/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0311 - f1Measurement: 0.8986 - precisionMeasurement: 0.9024 - recallMeasurement: 0.8948 - auc: 0.9973 - val_loss: 0.5228 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.7389
# Epoch 128/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0274 - f1Measurement: 0.9221 - precisionMeasurement: 0.9221 - recallMeasurement: 0.9221 - auc: 0.9988 - val_loss: 0.5214 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7404
# Epoch 129/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0305 - f1Measurement: 0.9052 - precisionMeasurement: 0.9052 - recallMeasurement: 0.9052 - auc: 0.9971 - val_loss: 0.5112 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7540
# Epoch 130/150
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0251 - f1Measurement: 0.9232 - precisionMeasurement: 0.9232 - recallMeasurement: 0.9232 - auc: 0.9981 - val_loss: 0.5021 - val_f1Measurement: 0.1186 - val_precisionMeasurement: 0.1296 - val_recallMeasurement: 0.1094 - val_auc: 0.7495
# Epoch 131/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0353 - f1Measurement: 0.8794 - precisionMeasurement: 0.8794 - recallMeasurement: 0.8794 - auc: 0.9967 - val_loss: 0.4924 - val_f1Measurement: 0.1167 - val_precisionMeasurement: 0.1250 - val_recallMeasurement: 0.1094 - val_auc: 0.7619
# Epoch 132/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0318 - f1Measurement: 0.9221 - precisionMeasurement: 0.9221 - recallMeasurement: 0.9221 - auc: 0.9972 - val_loss: 0.4822 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.7426
# Epoch 133/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0250 - f1Measurement: 0.9116 - precisionMeasurement: 0.9201 - recallMeasurement: 0.9036 - auc: 0.9983 - val_loss: 0.4839 - val_f1Measurement: 0.1186 - val_precisionMeasurement: 0.1296 - val_recallMeasurement: 0.1094 - val_auc: 0.7643
# Epoch 134/150
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0340 - f1Measurement: 0.8953 - precisionMeasurement: 0.9028 - recallMeasurement: 0.8880 - auc: 0.9972 - val_loss: 0.4899 - val_f1Measurement: 0.1186 - val_precisionMeasurement: 0.1296 - val_recallMeasurement: 0.1094 - val_auc: 0.7065
# Epoch 135/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0357 - f1Measurement: 0.8676 - precisionMeasurement: 0.8721 - recallMeasurement: 0.8633 - auc: 0.9958 - val_loss: 0.4915 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.7279
# Epoch 136/150
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0461 - f1Measurement: 0.9222 - precisionMeasurement: 0.9310 - recallMeasurement: 0.9143 - auc: 0.9985 - val_loss: 0.5040 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.7274
# Epoch 137/150
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0271 - f1Measurement: 0.9232 - precisionMeasurement: 0.9232 - recallMeasurement: 0.9232 - auc: 0.9980 - val_loss: 0.5230 - val_f1Measurement: 0.1356 - val_precisionMeasurement: 0.1481 - val_recallMeasurement: 0.1250 - val_auc: 0.6621
# Epoch 138/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0312 - f1Measurement: 0.8701 - precisionMeasurement: 0.8701 - recallMeasurement: 0.8701 - auc: 0.9971 - val_loss: 0.5123 - val_f1Measurement: 0.1333 - val_precisionMeasurement: 0.1429 - val_recallMeasurement: 0.1250 - val_auc: 0.6618
# Epoch 139/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0229 - f1Measurement: 0.9560 - precisionMeasurement: 0.9643 - recallMeasurement: 0.9479 - auc: 0.9992 - val_loss: 0.5118 - val_f1Measurement: 0.1379 - val_precisionMeasurement: 0.1538 - val_recallMeasurement: 0.1250 - val_auc: 0.6982
# Epoch 140/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0393 - f1Measurement: 0.8686 - precisionMeasurement: 0.8826 - recallMeasurement: 0.8555 - auc: 0.9947 - val_loss: 0.5085 - val_f1Measurement: 0.1429 - val_precisionMeasurement: 0.1667 - val_recallMeasurement: 0.1250 - val_auc: 0.6641
# Epoch 141/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0260 - f1Measurement: 0.9023 - precisionMeasurement: 0.9104 - recallMeasurement: 0.8945 - auc: 0.9976 - val_loss: 0.5050 - val_f1Measurement: 0.1639 - val_precisionMeasurement: 0.1724 - val_recallMeasurement: 0.1562 - val_auc: 0.6939
# Epoch 142/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0275 - f1Measurement: 0.9388 - precisionMeasurement: 0.9468 - recallMeasurement: 0.9310 - auc: 0.9985 - val_loss: 0.5086 - val_f1Measurement: 0.1774 - val_precisionMeasurement: 0.1833 - val_recallMeasurement: 0.1719 - val_auc: 0.6836
# Epoch 143/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0286 - f1Measurement: 0.9141 - precisionMeasurement: 0.9141 - recallMeasurement: 0.9141 - auc: 0.9978 - val_loss: 0.5200 - val_f1Measurement: 0.1639 - val_precisionMeasurement: 0.1724 - val_recallMeasurement: 0.1562 - val_auc: 0.6855
# Epoch 144/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0220 - f1Measurement: 0.9143 - precisionMeasurement: 0.9143 - recallMeasurement: 0.9143 - auc: 0.9988 - val_loss: 0.5410 - val_f1Measurement: 0.1290 - val_precisionMeasurement: 0.1333 - val_recallMeasurement: 0.1250 - val_auc: 0.7100
# Epoch 145/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0287 - f1Measurement: 0.9401 - precisionMeasurement: 0.9401 - recallMeasurement: 0.9401 - auc: 0.9980 - val_loss: 0.5677 - val_f1Measurement: 0.1148 - val_precisionMeasurement: 0.1207 - val_recallMeasurement: 0.1094 - val_auc: 0.6969
# Epoch 146/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0358 - f1Measurement: 0.9065 - precisionMeasurement: 0.9065 - recallMeasurement: 0.9065 - auc: 0.9864 - val_loss: 0.5935 - val_f1Measurement: 0.1228 - val_precisionMeasurement: 0.1400 - val_recallMeasurement: 0.1094 - val_auc: 0.6840
# Epoch 147/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0386 - f1Measurement: 0.8848 - precisionMeasurement: 0.8893 - recallMeasurement: 0.8805 - auc: 0.9964 - val_loss: 0.6055 - val_f1Measurement: 0.1207 - val_precisionMeasurement: 0.1346 - val_recallMeasurement: 0.1094 - val_auc: 0.6969
# Epoch 148/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0225 - f1Measurement: 0.9377 - precisionMeasurement: 0.9541 - recallMeasurement: 0.9224 - auc: 0.9992 - val_loss: 0.6197 - val_f1Measurement: 0.1148 - val_precisionMeasurement: 0.1207 - val_recallMeasurement: 0.1094 - val_auc: 0.7109
# Epoch 149/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0264 - f1Measurement: 0.9315 - precisionMeasurement: 0.9315 - recallMeasurement: 0.9315 - auc: 0.9985 - val_loss: 0.5973 - val_f1Measurement: 0.1290 - val_precisionMeasurement: 0.1333 - val_recallMeasurement: 0.1250 - val_auc: 0.7017
# Epoch 150/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0302 - f1Measurement: 0.8622 - precisionMeasurement: 0.8622 - recallMeasurement: 0.8622 - auc: 0.9970 - val_loss: 0.5607 - val_f1Measurement: 0.1148 - val_precisionMeasurement: 0.1207 - val_recallMeasurement: 0.1094 - val_auc: 0.7151

# %%
# Evaluates the trained  model on the test data and returns the values of the  metrics
scores = CNNModel.evaluate(testX, testY) 
print("--------------------------------------------------------------------------------------------------------------------")

# Evaluates the trained model on the test data and declares the loss, accuracy 
# f1_score, precision and recall
loss, accuracy, f1_score, precision, recall = CNNModel.evaluate(testX, testY)
print("--------------------------------------------------------------------------------------------------------------------")

# Used to Print the Final CNN Accuracy of the model
print("Final Results for The CNN Model")
print("F1 Accuracy of: {:.2f}".format(scores[1]),'%')    # Print Accuracy of Model
print("With a Loss of: {:.2f}".format(scores[0]),'%')    # Print Loss of Model
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5607 - f1Measurement: 0.1148 - precisionMeasurement: 0.1207 - recallMeasurement: 0.1094 - auc: 0.7151
# --------------------------------------------------------------------------------------------------------------------
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5607 - f1Measurement: 0.1148 - precisionMeasurement: 0.1207 - recallMeasurement: 0.1094 - auc: 0.7151
# --------------------------------------------------------------------------------------------------------------------
# Final Results for The CNN Model
# F1 Accuracy of: 0.11 %
# With a Loss of: 0.56 %
