# %%
# The following section is used to generate information about the datasets so these 
# variables can be initialised in the CNN Model. The information gathered here will
# also be used to determine an appropiate size of the training and testing datasets.
import os                                                   # Import os to change the information surrounding the enviroment 
from keras.preprocessing.image import ImageDataGenerator    # Create tensorflow image batches using data augmentation.
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
locationOfDataset = '/home/dmr/DatasetForExperiments/ransomware/'
batches = ImageDataGenerator().flow_from_directory(directory=locationOfDataset, 
                                                   target_size=(64,64), 
                                                   batch_size=202)

# Print information about Images 
imgs, labels = next(batches)
print("Number of Images and Size of Images: ",imgs.shape) # Images with width x length x depth
print("Number of Images and Families: ",labels.shape) # Lablels with batch_size, number of classes
# Out:
# 2023-05-05 14:39:09.481486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Found 101 images belonging to 10 classes.
# Number of Images and Size of Images:  (101, 64, 64, 3)
# Number of Images and Families:  (101, 10)

# %%
# This section will cover the necessary steps used to split the scareware dataset
# into training and testing to evaluate the effectiveness of this convolutional neural 
# network model based on the scareware samples.
import numpy as np                                   # Provides the ability to use numerical data to convert the .dex files to greyscale images
import scipy as sp                                   # Provides the use of algorithms to be used 
from PIL import Image                                # Allow for processing of images

# Splitting the Dataset into Training and testing with a test size of 30% of overall 
# samples in the dataset. 
from sklearn.model_selection import train_test_split    # Used to split the dataset

# Split up the data set, 30% testing 70% training
trainX, testX, trainY, testY = train_test_split(imgs/255.,labels, test_size=0.1)

# Print the information regarding the training and testing sample sizes
#print("Size of Training Set: ", trainX.shape)                   # Print training set information
#print("Size of Testing Set: ",testX.shape)                      # Print testing set information
print("Number of Samples in Training Set: ",trainY.shape)   # Print training set information
print("Number of Samples in Testing Set: ",testY.shape)     # Print testing set information
# Out:
# Number of Samples in Training Set:  (90, 10)
# Number of Samples in Testing Set:  (11, 10)

# %%
# The Convolutional Neural Network Model
# This section will encompass the aspects surrounding the convultional neural network
# which was used for the experimentation of this research. 
import keras                                            # Import keras
import tensorflow                                       # Import tensorflow
from keras.models import Sequential, Input, Model       # Used for CNN model regarding Models
from keras.layers import Dense, Dropout, Flatten        # Used for CNN model regarding Layers
from keras.layers import Conv2D, MaxPooling2D           # Used for CNN model regarding Layers
from tensorflow.keras.layers import BatchNormalization  # Layer used to normalise inputs
from tensorflow.keras.metrics import AUC                # Used estimate to Area Under Curve

noOfFamilies = 10 # Number of Families in the Sample

# Function used to create the layers of the convolutional neural network model. These parameters were
# constantly changed throughout testing in order to obtain the best possible results. Within this model 
# there are 10 main layers and each layers parameters are explained in detail. 
def CNNModel():
    CNNModel = Sequential()        # Sequential Model is used the experiments

    # Convolutional Layer: With relu Activation, 30 filters, and a kernel size of 3 x 3
    CNNModel.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(64,64,3)))                # Layer 1 

    # Max Pooling Layer: With a pool size of 2 x 2
    CNNModel.add(MaxPooling2D(pool_size=(2, 2)))            # Layer 2
    
    # Convolutional Layer: 16 filters and kernel size of 3 x 3 
    CNNModel.add(Conv2D(18, (3, 3), activation='relu'))     # Layer 3
    
    # Max Pooling Layer: Pool size of 2 x 2 
    CNNModel.add(MaxPooling2D(pool_size=(2, 2)))            # Layer 4
    
    # Drop Out Layer: This layer used to drop 25% of neurons in the model .
    CNNModel.add(Dropout(0.25))                             # Layer 5
    
    # Flatten Layer
    CNNModel.add(Flatten())                                 # Layer 6
    
    # Dense/Fully Connected Layer : 128 Neurons using the relu activation function
    CNNModel.add(Dense(128, activation='relu'))             # Layer 7
    
    # Drop Out Layer: This layer used to drop 50% of neurons in the model.
    CNNModel.add(Dropout(0.5))                              # Layer 8
    
    # Dense/Fully Connected Layer : 50 Neurons using the relu activation function
    CNNModel.add(Dense(50, activation='relu'))              # Layer 9
    
    # Dense/Fully Connected Layer : number of families neurons, using the softmax activation function
    CNNModel.add(Dense(noOfFamilies, activation='softmax')) # Layer 10
    
    CNNModel.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
    return CNNModel     # Return the Convolutional Neural Network Model

# %%
# Measure the effectiveness of the model. This section is used to generate the results of the 
# corresponding convolutional neural network. For the purpose of this mode, there are three main 
# measurements which have to be declared. These are recall, preicision and f1. Listed below
# are the neccessary formulas which are required to obtain these results.
from keras import backend as K

# Recall Measurement
def recallMeasurement(testY, yPrediction):
    true_positives = K.sum(K.round(K.clip(testY * yPrediction, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(testY, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# Precision Measurement
def precisionMeasurement(testY, yPrediction):
    true_positives = K.sum(K.round(K.clip(testY * yPrediction, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(yPrediction, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# F1 Measurement
def f1Measurement(testY, yPrediction):
    precision = precisionMeasurement(testY, yPrediction)
    recall = recallMeasurement(testY, yPrediction)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Initialise the Model
CNNModel = CNNModel()
# Out:
# 2023-05-05 14:39:11.190892: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-05-05 14:39:11.461321: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-05-05 14:39:11.461354: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pop-os): /proc/driver/nvidia/version does not exist
# 2023-05-05 14:39:11.461886: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 14:39:11.468696: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1999965000 Hz
# 2023-05-05 14:39:11.469499: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x16e2620 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-05-05 14:39:11.469522: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %%
# Print the Information of the Model. This includes the information surrounding 
# the layers of the models as well as the number of total parameters
CNNModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 18)        5202
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 18)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 18)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3528)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               451712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# =================================================================
# Total params: 464,770
# Trainable params: 464,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
trainY.shape                            # Returns the shape of the trainY array 
trainY_new = np.argmax(trainY, axis=1)  # Converts the trainY array to an array of integers 
trainY_new                              # Returns the array of integer labels
# Out:
# array([3, 8, 2, 3, 4, 6, 9, 7, 7, 9, 5, 7, 5, 3, 8, 5, 0, 4, 9, 5, 4, 2,
#        9, 7, 8, 1, 2, 1, 9, 3, 0, 0, 6, 2, 3, 6, 3, 4, 8, 4, 9, 1, 8, 9,
#        9, 7, 1, 1, 3, 5, 6, 2, 7, 8, 2, 3, 5, 5, 0, 6, 2, 5, 9, 8, 9, 8,
#        0, 1, 6, 8, 4, 4, 6, 1, 1, 0, 0, 4, 5, 2, 8, 0, 3, 1, 6, 7, 8, 4,
#        6, 7])

# %%
# This section of the model imports the class_weight function from the sklearn.utils 
# library. This is used to compute the class weights for a multi-class classification problem.
# The weightOfModel computes the class weights based on the class distribution found in the 
# training set. The class_weight parameter is set to balanced which means that the class 
# weights are automatically adjusted in acorrdance with the information obtained from the 
# input data.

from sklearn.utils import class_weight # Used to compute the class weights for a multi-class classification system
weightOfModel = class_weight.compute_class_weight(class_weight = 'balanced',
                                                 classes = np.unique(trainY_new),
                                                 y = trainY_new)

# This code is used to map each unique class label in the training set trainY_new variable. 
# This is then uses the class_weight variable initialised above. 
weightOfModel = {l:c for l,c in zip(np.unique(trainY_new), weightOfModel)}

# %%
# This is used to compile the Convolutional Neural network Model. It uses the adam optimiser, 
# computes loss using binary_crossentropy and then calculates the measurements listed before.
CNNModel.compile(optimizer='adam', 
                    loss='binary_crossentropy', 
                    metrics=[f1Measurement,precisionMeasurement, 
                    recallMeasurement,
                    AUC()])

# %%
# This section of the model is used to trained the convolutional neural network model. 
# This is achieved by using the fit() method from the Keras API of the TensorFlow library which 
# was imported previously. Here is where the number of epochs are declared for the model also
CNNModel.fit(trainX, trainY, validation_data=(testX, testY), 
                epochs=150,  
                class_weight=weightOfModel)
# Out:
# 2023-05-05 14:39:11.630780: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Epoch 1/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.6823 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.4554 - val_loss: 0.5519 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4532
# Epoch 2/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.5528 - f1Measurement: 0.0162 - precisionMeasurement: 0.0729 - recallMeasurement: 0.0091 - auc: 0.5207 - val_loss: 0.4341 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.4458
# Epoch 3/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4749 - f1Measurement: 0.0744 - precisionMeasurement: 0.1517 - recallMeasurement: 0.0494 - auc: 0.4903 - val_loss: 0.3705 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5078
# Epoch 4/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.4365 - f1Measurement: 0.0733 - precisionMeasurement: 0.4028 - recallMeasurement: 0.0416 - auc: 0.4990 - val_loss: 0.3473 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5565
# Epoch 5/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4116 - f1Measurement: 0.0291 - precisionMeasurement: 0.2292 - recallMeasurement: 0.0155 - auc: 0.5386 - val_loss: 0.3329 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5615
# Epoch 6/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3902 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.4800 - val_loss: 0.3271 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5611
# Epoch 7/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.3660 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5447 - val_loss: 0.3248 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5638
# Epoch 8/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3550 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.5614 - val_loss: 0.3194 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.5937
# Epoch 9/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3318 - f1Measurement: 0.0177 - precisionMeasurement: 0.2917 - recallMeasurement: 0.0091 - auc: 0.6515 - val_loss: 0.3119 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.6547
# Epoch 10/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.3243 - f1Measurement: 0.0290 - precisionMeasurement: 0.2639 - recallMeasurement: 0.0155 - auc: 0.6506 - val_loss: 0.3073 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.7259
# Epoch 11/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.3303 - f1Measurement: 0.0000e+00 - precisionMeasurement: 0.0000e+00 - recallMeasurement: 0.0000e+00 - auc: 0.6363 - val_loss: 0.3002 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.7984
# Epoch 12/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3151 - f1Measurement: 0.0629 - precisionMeasurement: 1.0000 - recallMeasurement: 0.0325 - auc: 0.6896 - val_loss: 0.2980 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.7723
# Epoch 13/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3082 - f1Measurement: 0.0177 - precisionMeasurement: 0.2917 - recallMeasurement: 0.0091 - auc: 0.7109 - val_loss: 0.2958 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.8003
# Epoch 14/150
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2893 - f1Measurement: 0.0971 - precisionMeasurement: 0.7361 - recallMeasurement: 0.0521 - auc: 0.8114 - val_loss: 0.2865 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.7934
# Epoch 15/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2925 - f1Measurement: 0.1871 - precisionMeasurement: 0.9444 - recallMeasurement: 0.1066 - auc: 0.7569 - val_loss: 0.2794 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.8131
# Epoch 16/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2777 - f1Measurement: 0.1785 - precisionMeasurement: 1.0000 - recallMeasurement: 0.0988 - auc: 0.8015 - val_loss: 0.2695 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.8678
# Epoch 17/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2736 - f1Measurement: 0.1464 - precisionMeasurement: 0.8194 - recallMeasurement: 0.0804 - auc: 0.8284 - val_loss: 0.2576 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.8994
# Epoch 18/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2712 - f1Measurement: 0.1789 - precisionMeasurement: 0.9139 - recallMeasurement: 0.1024 - auc: 0.8364 - val_loss: 0.2490 - val_f1Measurement: 0.0000e+00 - val_precisionMeasurement: 0.0000e+00 - val_recallMeasurement: 0.0000e+00 - val_auc: 0.9105
# Epoch 19/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2505 - f1Measurement: 0.2454 - precisionMeasurement: 0.9080 - recallMeasurement: 0.1443 - auc: 0.8711 - val_loss: 0.2411 - val_f1Measurement: 0.3077 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.1818 - val_auc: 0.9229
# Epoch 20/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2506 - f1Measurement: 0.2762 - precisionMeasurement: 0.7728 - recallMeasurement: 0.1687 - auc: 0.8698 - val_loss: 0.2355 - val_f1Measurement: 0.3077 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.1818 - val_auc: 0.9279
# Epoch 21/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.2317 - f1Measurement: 0.3332 - precisionMeasurement: 0.8823 - recallMeasurement: 0.2089 - auc: 0.9012 - val_loss: 0.2311 - val_f1Measurement: 0.3077 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.1818 - val_auc: 0.9279
# Epoch 22/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.2085 - f1Measurement: 0.5229 - precisionMeasurement: 0.9045 - recallMeasurement: 0.3689 - auc: 0.9295 - val_loss: 0.2264 - val_f1Measurement: 0.3077 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.1818 - val_auc: 0.9403
# Epoch 23/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1988 - f1Measurement: 0.5608 - precisionMeasurement: 0.8619 - recallMeasurement: 0.4208 - auc: 0.9441 - val_loss: 0.2022 - val_f1Measurement: 0.3077 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.1818 - val_auc: 0.9559
# Epoch 24/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1865 - f1Measurement: 0.5596 - precisionMeasurement: 0.9438 - recallMeasurement: 0.4037 - auc: 0.9601 - val_loss: 0.1952 - val_f1Measurement: 0.4286 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.2727 - val_auc: 0.9472
# Epoch 25/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1888 - f1Measurement: 0.6067 - precisionMeasurement: 0.8647 - recallMeasurement: 0.4689 - auc: 0.9385 - val_loss: 0.1982 - val_f1Measurement: 0.6250 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.4545 - val_auc: 0.9371
# Epoch 26/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1622 - f1Measurement: 0.6492 - precisionMeasurement: 0.9035 - recallMeasurement: 0.5123 - auc: 0.9681 - val_loss: 0.1942 - val_f1Measurement: 0.5333 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.3636 - val_auc: 0.9449
# Epoch 27/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.1782 - f1Measurement: 0.6321 - precisionMeasurement: 0.9230 - recallMeasurement: 0.4821 - auc: 0.9625 - val_loss: 0.1833 - val_f1Measurement: 0.7059 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.5455 - val_auc: 0.9518
# Epoch 28/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1645 - f1Measurement: 0.6239 - precisionMeasurement: 0.8431 - recallMeasurement: 0.4972 - auc: 0.9681 - val_loss: 0.1690 - val_f1Measurement: 0.7059 - val_precisionMeasurement: 1.0000 - val_recallMeasurement: 0.5455 - val_auc: 0.9665
# Epoch 29/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1615 - f1Measurement: 0.6489 - precisionMeasurement: 0.9773 - recallMeasurement: 0.5008 - auc: 0.9695 - val_loss: 0.1587 - val_f1Measurement: 0.7368 - val_precisionMeasurement: 0.8750 - val_recallMeasurement: 0.6364 - val_auc: 0.9720
# Epoch 30/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.1450 - f1Measurement: 0.6810 - precisionMeasurement: 0.9043 - recallMeasurement: 0.5647 - auc: 0.9820 - val_loss: 0.1548 - val_f1Measurement: 0.7368 - val_precisionMeasurement: 0.8750 - val_recallMeasurement: 0.6364 - val_auc: 0.9766
# Epoch 31/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.1241 - f1Measurement: 0.7876 - precisionMeasurement: 0.8908 - recallMeasurement: 0.7062 - auc: 0.9812 - val_loss: 0.1524 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9743
# Epoch 32/150
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1089 - f1Measurement: 0.8520 - precisionMeasurement: 0.9239 - recallMeasurement: 0.7911 - auc: 0.9922 - val_loss: 0.1466 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9757
# Epoch 33/150
# 3/3 [==============================] - 0s 51ms/step - loss: 0.1225 - f1Measurement: 0.8151 - precisionMeasurement: 0.9054 - recallMeasurement: 0.7413 - auc: 0.9868 - val_loss: 0.1476 - val_f1Measurement: 0.7368 - val_precisionMeasurement: 0.8750 - val_recallMeasurement: 0.6364 - val_auc: 0.9692
# Epoch 34/150
# 3/3 [==============================] - 0s 52ms/step - loss: 0.1106 - f1Measurement: 0.8345 - precisionMeasurement: 0.9345 - recallMeasurement: 0.7556 - auc: 0.9929 - val_loss: 0.1630 - val_f1Measurement: 0.6667 - val_precisionMeasurement: 0.8571 - val_recallMeasurement: 0.5455 - val_auc: 0.9564
# Epoch 35/150
# 3/3 [==============================] - 0s 54ms/step - loss: 0.1143 - f1Measurement: 0.8051 - precisionMeasurement: 0.8580 - recallMeasurement: 0.7593 - auc: 0.9853 - val_loss: 0.1423 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9702
# Epoch 36/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0912 - f1Measurement: 0.8599 - precisionMeasurement: 0.9172 - recallMeasurement: 0.8107 - auc: 0.9953 - val_loss: 0.1254 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9757
# Epoch 37/150
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0870 - f1Measurement: 0.8975 - precisionMeasurement: 0.9734 - recallMeasurement: 0.8351 - auc: 0.9959 - val_loss: 0.1263 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9826
# Epoch 38/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0848 - f1Measurement: 0.8735 - precisionMeasurement: 0.9185 - recallMeasurement: 0.8340 - auc: 0.9932 - val_loss: 0.1370 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9761
# Epoch 39/150
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0747 - f1Measurement: 0.9570 - precisionMeasurement: 0.9903 - recallMeasurement: 0.9260 - auc: 0.9974 - val_loss: 0.1374 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9660
# Epoch 40/150
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0793 - f1Measurement: 0.9032 - precisionMeasurement: 0.9694 - recallMeasurement: 0.8478 - auc: 0.9965 - val_loss: 0.1345 - val_f1Measurement: 0.8000 - val_precisionMeasurement: 0.8889 - val_recallMeasurement: 0.7273 - val_auc: 0.9674
# Epoch 41/150
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0656 - f1Measurement: 0.9487 - precisionMeasurement: 0.9728 - recallMeasurement: 0.9260 - auc: 0.9984 - val_loss: 0.1247 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9784
# Epoch 42/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0615 - f1Measurement: 0.9673 - precisionMeasurement: 0.9740 - recallMeasurement: 0.9611 - auc: 0.9982 - val_loss: 0.1166 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9871
# Epoch 43/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0640 - f1Measurement: 0.9297 - precisionMeasurement: 0.9799 - recallMeasurement: 0.8844 - auc: 0.9984 - val_loss: 0.1124 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.9816
# Epoch 44/150
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0691 - f1Measurement: 0.9008 - precisionMeasurement: 0.9368 - recallMeasurement: 0.8675 - auc: 0.9969 - val_loss: 0.1293 - val_f1Measurement: 0.8571 - val_precisionMeasurement: 0.9000 - val_recallMeasurement: 0.8182 - val_auc: 0.9619
# Epoch 45/150
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0516 - f1Measurement: 0.9670 - precisionMeasurement: 0.9845 - recallMeasurement: 0.9506 - auc: 0.9991 - val_loss: 0.1687 - val_f1Measurement: 0.8571 - val_precisionMeasurement: 0.9000 - val_recallMeasurement: 0.8182 - val_auc: 0.9614
# Epoch 46/150
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0680 - f1Measurement: 0.9118 - precisionMeasurement: 0.9240 - recallMeasurement: 0.8999 - auc: 0.9975 - val_loss: 0.1500 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9224
# Epoch 47/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0541 - f1Measurement: 0.9383 - precisionMeasurement: 0.9597 - recallMeasurement: 0.9182 - auc: 0.9989 - val_loss: 0.1393 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9164
# Epoch 48/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0558 - f1Measurement: 0.9355 - precisionMeasurement: 0.9388 - recallMeasurement: 0.9324 - auc: 0.9992 - val_loss: 0.1327 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9601
# Epoch 49/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0490 - f1Measurement: 0.9631 - precisionMeasurement: 0.9717 - recallMeasurement: 0.9547 - auc: 0.9986 - val_loss: 0.1287 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9725
# Epoch 50/150
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0548 - f1Measurement: 0.9471 - precisionMeasurement: 0.9750 - recallMeasurement: 0.9209 - auc: 0.9977 - val_loss: 0.1272 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9743
# Epoch 51/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0478 - f1Measurement: 0.9381 - precisionMeasurement: 0.9493 - recallMeasurement: 0.9273 - auc: 0.9981 - val_loss: 0.1239 - val_f1Measurement: 0.8571 - val_precisionMeasurement: 0.9000 - val_recallMeasurement: 0.8182 - val_auc: 0.9711
# Epoch 52/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0390 - f1Measurement: 0.9881 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9767 - auc: 1.0000 - val_loss: 0.1299 - val_f1Measurement: 0.8571 - val_precisionMeasurement: 0.9000 - val_recallMeasurement: 0.8182 - val_auc: 0.9316
# Epoch 53/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0419 - f1Measurement: 0.9707 - precisionMeasurement: 0.9740 - recallMeasurement: 0.9675 - auc: 0.9995 - val_loss: 0.1373 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9325
# Epoch 54/150
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0443 - f1Measurement: 0.9550 - precisionMeasurement: 0.9582 - recallMeasurement: 0.9520 - auc: 0.9983 - val_loss: 0.1260 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9715
# Epoch 55/150
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0316 - f1Measurement: 0.9594 - precisionMeasurement: 0.9670 - recallMeasurement: 0.9520 - auc: 0.9997 - val_loss: 0.1177 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.9793
# Epoch 56/150
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0407 - f1Measurement: 0.9570 - precisionMeasurement: 0.9651 - recallMeasurement: 0.9492 - auc: 0.9991 - val_loss: 0.1113 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.9821
# Epoch 57/150
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0332 - f1Measurement: 0.9850 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9767 - auc: 0.9998 - val_loss: 0.1083 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9839
# Epoch 58/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0391 - f1Measurement: 0.9745 - precisionMeasurement: 0.9903 - recallMeasurement: 0.9598 - auc: 0.9998 - val_loss: 0.1143 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9830
# Epoch 59/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0282 - f1Measurement: 0.9850 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9767 - auc: 0.9999 - val_loss: 0.1190 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9789
# Epoch 60/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0364 - f1Measurement: 0.9523 - precisionMeasurement: 0.9567 - recallMeasurement: 0.9479 - auc: 0.9991 - val_loss: 0.1282 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9362
# Epoch 61/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0269 - f1Measurement: 0.9785 - precisionMeasurement: 0.9818 - recallMeasurement: 0.9754 - auc: 0.9998 - val_loss: 0.1343 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9293
# Epoch 62/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0292 - f1Measurement: 0.9670 - precisionMeasurement: 0.9845 - recallMeasurement: 0.9506 - auc: 0.9998 - val_loss: 0.1384 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9679
# Epoch 63/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0295 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 0.9999 - val_loss: 0.1449 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9293
# Epoch 64/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0203 - f1Measurement: 0.9921 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9845 - auc: 1.0000 - val_loss: 0.1526 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9339
# Epoch 65/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0330 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1358 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9320
# Epoch 66/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0202 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1372 - val_f1Measurement: 0.8571 - val_precisionMeasurement: 0.9000 - val_recallMeasurement: 0.8182 - val_auc: 0.8907
# Epoch 67/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0338 - f1Measurement: 0.9651 - precisionMeasurement: 0.9734 - recallMeasurement: 0.9570 - auc: 0.9993 - val_loss: 0.1392 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9311
# Epoch 68/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0215 - f1Measurement: 0.9661 - precisionMeasurement: 0.9661 - recallMeasurement: 0.9661 - auc: 0.9998 - val_loss: 0.1366 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9325
# Epoch 69/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0300 - f1Measurement: 0.9775 - precisionMeasurement: 0.9906 - recallMeasurement: 0.9648 - auc: 0.9998 - val_loss: 0.1354 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 70/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0249 - f1Measurement: 0.9906 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9818 - auc: 1.0000 - val_loss: 0.1386 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.9417
# Epoch 71/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0232 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 0.9997 - val_loss: 0.1415 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8944
# Epoch 72/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0178 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1454 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8944
# Epoch 73/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0187 - f1Measurement: 0.9850 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9767 - auc: 1.0000 - val_loss: 0.1492 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8916
# Epoch 74/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0154 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1496 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8921
# Epoch 75/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0200 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1552 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9311
# Epoch 76/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0294 - f1Measurement: 0.9537 - precisionMeasurement: 0.9651 - recallMeasurement: 0.9428 - auc: 0.9993 - val_loss: 0.1485 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9343
# Epoch 77/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0165 - f1Measurement: 0.9868 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9740 - auc: 1.0000 - val_loss: 0.1443 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9371
# Epoch 78/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0197 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1355 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9348
# Epoch 79/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0181 - f1Measurement: 0.9823 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9740 - auc: 0.9999 - val_loss: 0.1347 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9316
# Epoch 80/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0100 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1405 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8958
# Epoch 81/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0319 - f1Measurement: 0.9764 - precisionMeasurement: 0.9831 - recallMeasurement: 0.9703 - auc: 0.9999 - val_loss: 0.1532 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.9362
# Epoch 82/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0153 - f1Measurement: 0.9767 - precisionMeasurement: 0.9767 - recallMeasurement: 0.9767 - auc: 0.9999 - val_loss: 0.1610 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.8921
# Epoch 83/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0239 - f1Measurement: 0.9742 - precisionMeasurement: 0.9825 - recallMeasurement: 0.9661 - auc: 0.9997 - val_loss: 0.1633 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9311
# Epoch 84/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0122 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1686 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9307
# Epoch 85/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0162 - f1Measurement: 0.9818 - precisionMeasurement: 0.9818 - recallMeasurement: 0.9818 - auc: 0.9999 - val_loss: 0.1665 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9307
# Epoch 86/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0136 - f1Measurement: 0.9890 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9845 - auc: 1.0000 - val_loss: 0.1507 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9339
# Epoch 87/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0105 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1327 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8958
# Epoch 88/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0180 - f1Measurement: 0.9828 - precisionMeasurement: 0.9906 - recallMeasurement: 0.9754 - auc: 0.9999 - val_loss: 0.1369 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8976
# Epoch 89/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0116 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1523 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8949
# Epoch 90/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0150 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1690 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9334
# Epoch 91/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0191 - f1Measurement: 0.9732 - precisionMeasurement: 0.9818 - recallMeasurement: 0.9648 - auc: 0.9998 - val_loss: 0.1759 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8907
# Epoch 92/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0162 - f1Measurement: 0.9906 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9818 - auc: 0.9999 - val_loss: 0.1690 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8916
# Epoch 93/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0161 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1628 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 94/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0107 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1649 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 95/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0073 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1731 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8916
# Epoch 96/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0200 - f1Measurement: 0.9831 - precisionMeasurement: 0.9831 - recallMeasurement: 0.9831 - auc: 0.9995 - val_loss: 0.1758 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8935
# Epoch 97/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0206 - f1Measurement: 0.9759 - precisionMeasurement: 0.9845 - recallMeasurement: 0.9675 - auc: 0.9998 - val_loss: 0.1635 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8930
# Epoch 98/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0082 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1540 - val_f1Measurement: 0.7619 - val_precisionMeasurement: 0.8000 - val_recallMeasurement: 0.7273 - val_auc: 0.8912
# Epoch 99/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0097 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1529 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.8930
# Epoch 100/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0130 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1558 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8958
# Epoch 101/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0081 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1652 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 102/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0100 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1749 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8944
# Epoch 103/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0084 - f1Measurement: 0.9914 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9831 - auc: 1.0000 - val_loss: 0.1819 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8972
# Epoch 104/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0118 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1778 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8972
# Epoch 105/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0107 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1692 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8962
# Epoch 106/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0106 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1733 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8949
# Epoch 107/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0101 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1855 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 108/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0109 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1982 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 109/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0089 - f1Measurement: 0.9914 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9831 - auc: 1.0000 - val_loss: 0.2041 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 110/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0129 - f1Measurement: 0.9890 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9845 - auc: 0.9999 - val_loss: 0.1991 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8949
# Epoch 111/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0056 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1896 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 112/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0179 - f1Measurement: 0.9779 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9570 - auc: 0.9997 - val_loss: 0.1844 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8939
# Epoch 113/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0139 - f1Measurement: 0.9767 - precisionMeasurement: 0.9767 - recallMeasurement: 0.9767 - auc: 0.9999 - val_loss: 0.1889 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8967
# Epoch 114/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0070 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1950 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8972
# Epoch 115/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0038 - f1Measurement: 0.9967 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1982 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8972
# Epoch 116/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0064 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.2055 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8967
# Epoch 117/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0066 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2088 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 118/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0064 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2160 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 119/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0108 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2258 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 120/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0091 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 0.9999 - val_loss: 0.2272 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 121/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0175 - f1Measurement: 0.9740 - precisionMeasurement: 0.9740 - recallMeasurement: 0.9740 - auc: 0.9998 - val_loss: 0.2053 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9008
# Epoch 122/150
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0084 - f1Measurement: 0.9954 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1899 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9008
# Epoch 123/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0063 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1765 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8976
# Epoch 124/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0115 - f1Measurement: 0.9845 - precisionMeasurement: 0.9845 - recallMeasurement: 0.9845 - auc: 0.9999 - val_loss: 0.1602 - val_f1Measurement: 0.7273 - val_precisionMeasurement: 0.7273 - val_recallMeasurement: 0.7273 - val_auc: 0.8967
# Epoch 125/150
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0119 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1562 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8994
# Epoch 126/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0117 - f1Measurement: 0.9954 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1571 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8935
# Epoch 127/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0067 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1569 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9348
# Epoch 128/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0101 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1576 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9357
# Epoch 129/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0094 - f1Measurement: 0.9831 - precisionMeasurement: 0.9831 - recallMeasurement: 0.9831 - auc: 1.0000 - val_loss: 0.1650 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 130/150
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0095 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1700 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 131/150
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0121 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 0.9999 - val_loss: 0.1778 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8958
# Epoch 132/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0073 - f1Measurement: 0.9954 - precisionMeasurement: 1.0000 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.1867 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8958
# Epoch 133/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0050 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1973 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 134/150
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0183 - f1Measurement: 0.9678 - precisionMeasurement: 0.9761 - recallMeasurement: 0.9597 - auc: 0.9999 - val_loss: 0.2000 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8962
# Epoch 135/150
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0077 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1911 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8935
# Epoch 136/150
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0053 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1721 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8972
# Epoch 137/150
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0035 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1630 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.9008
# Epoch 138/150
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0082 - f1Measurement: 0.9936 - precisionMeasurement: 0.9936 - recallMeasurement: 0.9936 - auc: 1.0000 - val_loss: 0.1650 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8999
# Epoch 139/150
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0048 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1765 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8976
# Epoch 140/150
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0034 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.1877 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8944
# Epoch 141/150
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0121 - f1Measurement: 0.9798 - precisionMeasurement: 0.9831 - recallMeasurement: 0.9767 - auc: 0.9999 - val_loss: 0.1954 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8916
# Epoch 142/150
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0054 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2032 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8921
# Epoch 143/150
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0097 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2014 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8967
# Epoch 144/150
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0096 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2021 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8990
# Epoch 145/150
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0075 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2084 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 146/150
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0087 - f1Measurement: 0.9831 - precisionMeasurement: 0.9831 - recallMeasurement: 0.9831 - auc: 1.0000 - val_loss: 0.2084 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8953
# Epoch 147/150
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0054 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2198 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8962
# Epoch 148/150
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0112 - f1Measurement: 0.9909 - precisionMeasurement: 0.9909 - recallMeasurement: 0.9909 - auc: 1.0000 - val_loss: 0.2365 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8990
# Epoch 149/150
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0106 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2254 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8967
# Epoch 150/150
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0056 - f1Measurement: 1.0000 - precisionMeasurement: 1.0000 - recallMeasurement: 1.0000 - auc: 1.0000 - val_loss: 0.2188 - val_f1Measurement: 0.8182 - val_precisionMeasurement: 0.8182 - val_recallMeasurement: 0.8182 - val_auc: 0.8967

# %%
# Evaluates the trained  model on the test data and returns the values of the  metrics
scores = CNNModel.evaluate(testX, testY) 
print("--------------------------------------------------------------------------------------------------------------------")

# Evaluates the trained model on the test data and declares the loss, accuracy 
# f1_score, precision and recall
loss, accuracy, f1_score, precision, recall = CNNModel.evaluate(testX, testY)
print("--------------------------------------------------------------------------------------------------------------------")

# Used to Print the Final CNN Accuracy of the model
print("Final Results for The CNN Model")
print("F1 Accuracy of: {:.2f}".format(scores[1]),'%')    # Print Accuracy of Model
print("With a Loss of: {:.2f}".format(scores[0]),'%')    # Print Loss of Model
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2188 - f1Measurement: 0.8182 - precisionMeasurement: 0.8182 - recallMeasurement: 0.8182 - auc: 0.8967
# --------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2188 - f1Measurement: 0.8182 - precisionMeasurement: 0.8182 - recallMeasurement: 0.8182 - auc: 0.8967
# --------------------------------------------------------------------------------------------------------------------
# Final Results for The CNN Model
# F1 Accuracy of: 0.82 %
# With a Loss of: 0.22 %
